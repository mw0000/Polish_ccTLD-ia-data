// %%
// 1. Installation

//install libraries
import org.archive.archivespark._
import org.archive.archivespark.functions._
import org.archive.archivespark.specific.warc._

// data files - generic path from docker run -v
val cdxPath = "/data/arc_cdx/*.cdx"
val warcPath = "/data/warc"

import org.apache.spark.sql.{Row, SparkSession}

val session = spark.newSession

// collect all records

val r = ArchiveSpark.load(WarcSpec.fromFiles(cdxPath, warcPath))

// %%
val researchYear = "2001"

// %%
// 2. Count ALL objects from research Year
// 2.1 get data for text/html & HTTP 200 for each Year
val t1 = r.filter(r => r.timestamp.startsWith(researchYear))

// %%
// 2.2 count all captures
t1.count()
// Out:
// 47162716

// %%
// 3. generate basic data frame

val m = t1.map(f=> (f.originalUrl,f.digest,f.status,f.mime))
val df = session.createDataFrame(m).toDF("originalUrl","digest","status","mime").cache()

// %%
df.show()
// Out:
// +--------------------+--------------------+------+---------+
// |         originalUrl|              digest|status|     mime|
// +--------------------+--------------------+------+---------+
// |http://www.stopkl...|CFJY5WTXRWLZM3B5Q...|   301|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|P4C4JU3ZFHYQ6OP46...|   301|text/html|
// |http://www.stopkl...|UFY6TJRXESSK4SW5M...|   301|text/html|
// |http://www.stopkl...|UFY6TJRXESSK4SW5M...|   301|text/html|
// |http://www.stopkl...|RHSJSKHLN5PUQBUNK...|   301|text/html|
// |http://www.stopkl...|RHSJSKHLN5PUQBUNK...|   301|text/html|
// |http://www.stopkl...|5J7D5UTD5RRF2HA6N...|   301|text/html|
// |http://www.stopkl...|DSQPHWBGC2GSCTAFH...|   301|text/html|
// |http://www.stopkl...|MVMN5J4NQUDHP65SZ...|   301|text/html|
// |http://www.stopkl...|MVMN5J4NQUDHP65SZ...|   301|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// +--------------------+--------------------+------+---------+
// only showing top 20 rows

// %%
// 4. Count distinct originalUrls
val dOu = df.select(df("originalUrl")).distinct.count()

// %%
dOu
// Out:
// 13918167

// %%
// 5. srednia i mediana liczby wersji na pojedynczy URL
import org.apache.spark.sql.functions.count
import org.apache.spark.sql.functions._

val mDu = df.groupBy("originalUrl").agg(count("digest") as "digests").orderBy(desc("digests")).cache()

// %%
mDu.show(false)
// Out:
// +--------------------------------------+-------+
// |originalUrl                           |digests|
// +--------------------------------------+-------+
// |http://www.wp.pl:80/robots.txt        |35116  |
// |http://of.pl:80/robots.txt            |27586  |
// |http://www.hg.pl:80/robots.txt        |25698  |
// |http://tools.ptc.pl:80/robots.txt     |15436  |
// |http://www.hg.pl:80/404.html          |15152  |
// |http://www.multinet.pl:80/robots.txt  |13486  |
// |http://www.alpha.pl:80/robots.txt     |12768  |
// |http://www.net-line.pl:80/robots.txt  |12134  |
// |http://www.itt.pl:80/robots.txt       |11462  |
// |http://www.alpha.pl:80/missing.html   |9500   |
// |http://katalog.wp.pl:80/www/index.html|8606   |
// |http://www.atcom.net.pl:80/robots.txt |8422   |
// |http://www.kki.net.pl:80/             |8364   |
// |http://free.eroskop.pl:80/robots.txt  |8234   |
// |http://viper.pl:80/robots.txt         |8116   |
// |http://error.punkt.pl:80/robots.txt   |8096   |
// |http://www.netservice.pl:80/robots.txt|8038   |
// |http://www.toya.net.pl:80/robots.txt  |7650   |
// |http://www.psi.com.pl:80/robots.txt   |7524   |
// |http://www.nets.com.pl:80/robots.txt  |7226   |
// +--------------------------------------+-------+
// only showing top 20 rows

// %%
// 5.1 mean
mDu.agg(avg("digests")).show()
// Out:
// +----------------+
// |    avg(digests)|
// +----------------+
// |3.38857236013909|
// +----------------+

// %%
// 5.2 median
mDu.agg(expr("percentile(digests, 0.5)").as("median")).cache().show()
// Out:
// +------+
// |median|
// +------+
// |   2.0|
// +------+

// %%
// tab 2. A - statusy inne niz 200
df.where("status != '200'").count()
// Out:
// 10818288

// %%
// tab 2. A - statusy HTML inne niz 200
df.where("mime == 'text/html'").where("status != '200'").count()
// Out:
// 10767076

// %%
// test pls
df.where("status != '200'").show(150)
// Out:
// +--------------------+--------------------+------+---------+
// |         originalUrl|              digest|status|     mime|
// +--------------------+--------------------+------+---------+
// |http://www.stopkl...|CFJY5WTXRWLZM3B5Q...|   301|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|P4C4JU3ZFHYQ6OP46...|   301|text/html|
// |http://www.stopkl...|UFY6TJRXESSK4SW5M...|   301|text/html|
// |http://www.stopkl...|UFY6TJRXESSK4SW5M...|   301|text/html|
// |http://www.stopkl...|RHSJSKHLN5PUQBUNK...|   301|text/html|
// |http://www.stopkl...|RHSJSKHLN5PUQBUNK...|   301|text/html|
// |http://www.stopkl...|5J7D5UTD5RRF2HA6N...|   301|text/html|
// |http://www.stopkl...|DSQPHWBGC2GSCTAFH...|   301|text/html|
// |http://www.stopkl...|MVMN5J4NQUDHP65SZ...|   301|text/html|
// |http://www.stopkl...|MVMN5J4NQUDHP65SZ...|   301|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://stopklatka...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|DSGSLMUVZ4QBFNSWI...|   301|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://stopklatka...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://stopklatka...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://stopklatka...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://stopklatka...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://stopklatka...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|XM2BRSMVE4JQ2V4GL...|   301|text/html|
// |http://www.stopkl...|V4CAEIHFUCZMTIOUQ...|   301|text/html|
// |http://www.stopkl...|V4CAEIHFUCZMTIOUQ...|   301|text/html|
// |http://www.stopkl...|HK6E6YI73TXOAODUC...|   301|text/html|
// |http://www.stopkl...|ER74U5KII6YPTJSVV...|   301|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|63A4EKEYDPMSDTKBC...|   301|text/html|
// |http://www.stopkl...|SQG5B5YXLIRWN3D7J...|   301|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|SGJB5YD5DSSTLZNN7...|   301|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://stopklatka...|IOMEZYLZWG5QRLMZB...|   301|text/html|
// |http://www.stopkl...|VAZN7V22OSRJTOY3B...|   301|text/html|
// |http://www.stopkl...|OJRRQ3YXBACKOKXFV...|   301|text/html|
// |http://www.stopkl...|OJRRQ3YXBACKOKXFV...|   301|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|A52K6CDL35FBC7GJ4...|   301|text/html|
// |http://www.stopkl...|JGQKXBJWUQN76V5LI...|   301|text/html|
// |http://www.stopkl...|A52K6CDL35FBC7GJ4...|   301|text/html|
// |http://www.stopkl...|JGQKXBJWUQN76V5LI...|   301|text/html|
// |http://www.stopkl...|H6Y5JPVIMG34GYJNA...|   301|text/html|
// |http://www.stopkl...|H6Y5JPVIMG34GYJNA...|   301|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|RZ6AOD276TEJZU4DG...|   301|text/html|
// |http://stopklatka...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|AHYHTULSKXRU7DS4X...|   301|text/html|
// |http://www.stopkl...|AHYHTULSKXRU7DS4X...|   301|text/html|
// |http://www.stopkl...|AHYHTULSKXRU7DS4X...|   301|text/html|
// |http://www.stopkl...|SOHYTWYAG7PT56DDR...|   301|text/html|
// |http://www.stopkl...|SOHYTWYAG7PT56DDR...|   301|text/html|
// |http://www.stopkl...|3BEHM5FK5PIITA5V2...|   301|text/html|
// |http://www.stopkl...|3BEHM5FK5PIITA5V2...|   301|text/html|
// |http://www.stopkl...|SOHYTWYAG7PT56DDR...|   301|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|SVEA4SZQOPANQEEUA...|   301|text/html|
// |http://www.stopkl...|SVEA4SZQOPANQEEUA...|   301|text/html|
// |http://www.stopkl...|SVEA4SZQOPANQEEUA...|   301|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|KYTLZGHZ6ENI2FE7Q...|   404|text/html|
// |http://www.stopkl...|LYAFYJLLUE4DIKPX7...|   301|text/html|
// |http://www.stopkl...|YYZKWAWQHOXDEYU52...|   301|text/html|
// |http://www.stopkl...|VK4KNRF25D4SC6CVU...|   301|text/html|
// |http://www.stopkl...|ZYJW7BZSIGAPFAJEJ...|   301|text/html|
// |http://www.stopkl...|ZYJW7BZSIGAPFAJEJ...|   301|text/html|
// |http://www.stopkl...|STII2IAHHIMFRBCTK...|   301|text/html|
// |http://www.stopkl...|KVAO7SIAAGMKHPGUU...|   301|text/html|
// |http://stopptak.c...|R72SUBXLG4LHI32DW...|   404|text/html|
// |http://stopptak.c...|UMW3J3GIQKI2VX2BH...|   404|text/html|
// |http://stopptak.c...|EXQUABOMSGN2WFT4C...|   404|text/html|
// |http://stopptak.c...|N646LVMOV37AXCWZK...|   404|text/html|
// |http://stopptak.c...|KC5KN2I27NZY7655A...|   404|text/html|
// |http://stopptak.c...|RT6KQBQXQMJWGRZEW...|   404|text/html|
// |http://stopptak.c...|VJFHJK3GHMGPMPIWC...|   404|text/html|
// |http://stopptak.c...|AVERLGKUNHXQGLKXQ...|   404|text/html|
// |http://stopptak.c...|JIYID3ZHPYULEWVIQ...|   404|text/html|
// |http://stopptak.c...|JDGAABHXPFQHESABJ...|   404|text/html|
// |http://stopptak.c...|SG4DTXEVTQUD2ZFRW...|   404|text/html|
// |http://stopptak.c...|CZOPUICRYVZJGF7J2...|   404|text/html|
// |http://stopptak.c...|QKQNGEQY3WMSDLFMD...|   404|text/html|
// |http://stopptak.c...|XF24XSHZ4JE3EEMUU...|   404|text/html|
// |http://stopptak.c...|4M2ODW2OB7WYOEYIX...|   404|text/html|
// |http://stopptak.c...|TQYGRPPOZ37MXCF7Y...|   404|text/html|
// |http://stopptak.c...|3QB4QQHBKKD2524TS...|   404|text/html|
// |http://stopptak.c...|COONML6O7KVZV3OXC...|   404|text/html|
// |http://stopptak.c...|75U7ZM57PGK2X3NKX...|   404|text/html|
// +--------------------+--------------------+------+---------+
// only showing top 150 rows

// %%
// tab basic2.2
// count distinct mime http 200
df.where("status == '200'").agg(countDistinct("mime")).show()
// Out:
// +--------------------+
// |count(DISTINCT mime)|
// +--------------------+
// |                 248|
// +--------------------+

// %%
// count all mimes counts
df.where("status == '200'").groupBy("mime").count().orderBy(desc("count")).cache().show(250)
// Out:
// +--------------------+--------+
// |                mime|   count|
// +--------------------+--------+
// |           text/html|27328568|
// |           image/gif| 3449178|
// |          image/jpeg| 2896882|
// |           alexa/dat| 1384634|
// |          text/plain|  849752|
// |            text/css|  115564|
// |application/octet...|   87790|
// |           image/png|   82098|
// |application/x-jav...|   55150|
// |                 unk|   12556|
// |     application/zip|   10212|
// |            text/xml|    8188|
// |audio/x-pn-realaudio|    7736|
// |application/x-msd...|    5064|
// |     application/pdf|    4578|
// |application/corel...|    4208|
// |           image/bmp|    3706|
// |            text/vnd|    2926|
// |          audio/mpeg|    2792|
// |     audio/x-mpegurl|    2562|
// |   application/x-tar|    2244|
// |application/posts...|    2118|
// |         image/pjpeg|    1954|
// |application/x-sho...|    1864|
// |  application/msword|    1548|
// |     image/x-xbitmap|    1442|
// |         audio/x-wav|    1318|
// |   application/x-tex|    1040|
// |          audio/midi|     856|
// |                 ose|     844|
// |application/x-dir...|     806|
// |     text/javascript|     762|
// |     application/vnd|     684|
// |          video/mpeg|     680|
// |audio/x-pn-realau...|     664|
// |      image/x-ms-bmp|     646|
// |   application/x-tcl|     544|
// |   application/x-rpm|     462|
// |application/x-poi...|     366|
// |            text/rtf|     364|
// |          image/tiff|     354|
// |      video/x-ms-asf|     274|
// |application/x-htt...|     270|
// |    application/smil|     258|
// |        image/x-icon|     250|
// |application/x-zip...|     248|
// |application/x-htt...|     232|
// |     video/quicktime|     218|
// |     video/x-msvideo|     216|
// |  application/x-java|     214|
// |          model/vrml|     210|
// |         text/x-java|     208|
// |     application/rtf|     206|
// |  application/x-gzip|     178|
// |    application/x-sh|     166|
// |      x-world/x-vrml|     166|
// |          text/x-tcl|     154|
// |application/x-x50...|     148|
// |  application/x-gtar|     146|
// |         www/unknown|     144|
// |text/x-server-par...|     142|
// |application/x-netcdf|     142|
// |     application/pps|     130|
// | application/x-troff|     126|
// |         audio/basic|     118|
// |   application/x-hdf|     114|
// |     aplications/dwg|     110|
// |          text/x-tex|     106|
// |       text/x-pascal|      98|
// |   application/x-tgz|      90|
// |   audio/x-realaudio|      90|
// |        audio/x-mpeg|      88|
// |application/x-com...|      88|
// |   application/x-rar|      88|
// |httpd/unix-directory|      82|
// |application/x-msm...|      82|
// |   application/x-rpr|      82|
// |application/x-deb...|      76|
// |           image/jpg|      76|
// |        audio/x-aiff|      74|
// |   application/x-dvi|      74|
// |           image/vnd|      74|
// |        message/news|      72|
// |  application/x-perl|      68|
// |       audio/x-scpls|      64|
// |application/dos-e...|      60|
// |          javascript|      56|
// |              image/|      56|
// |      message/rfc822|      52|
// |         image/x-png|      50|
// |           audio/wav|      50|
// |         text/x-csrc|      50|
// | application/x-bzip2|      48|
// |       video/unknown|      48|
// |        udio/x-scpls|      48|
// |         audio/x-mp3|      48|
// |           text/sgml|      46|
// |       text/c-source|      46|
// |application/x-msd...|      44|
// |      chemical/x-pdb|      38|
// |application/mac-b...|      38|
// |application/x-fut...|      36|
// |           text/x-sh|      36|
// |application/power...|      36|
// |   application/x-cdf|      36|
// |            ext/html|      34|
// |        image/bitmap|      32|
// |application/x-ns-...|      32|
// |             vms/exe|      32|
// |application/x-tro...|      32|
// |application/x-wai...|      32|
// |application/x-msw...|      32|
// | magnus-internal/cgi|      32|
// |        text/x-vcard|      32|
// |application/x-pkc...|      32|
// |application/x-rar...|      32|
// |           audio/mid|      30|
// |   application/x-lzx|      30|
// |         audio/mpeg3|      30|
// |application/font-...|      30|
// |       drawing/x-dwf|      30|
// |      video/x-ms-wmv|      30|
// |text/comma-separa...|      28|
// |application/x-com...|      26|
// |           image/ico|      24|
// |           image/swf|      24|
// |httpd/send-as-is-...|      24|
// |   application/x-ica|      24|
// |application/mac-c...|      24|
// |           httpd/gra|      22|
// | application/x-trash|      22|
// |text/tab-separate...|      22|
// |      image/x-bitmap|      22|
// |application/x-gunzip|      22|
// |application/x-tro...|      22|
// |         text/x-sgml|      20|
// |application/pgp-s...|      18|
// |     image/x-xpixmap|      18|
// |     application/exe|      18|
// |application/x-che...|      18|
// |           image/url|      18|
// |application/x-htt...|      16|
// |application/x-htt...|      14|
// |     application/xml|      14|
// |     application/rar|      12|
// |       text/x-c-code|      12|
// |         scene/blend|      12|
// |   application/x-zip|      12|
// |application/x-stu...|      12|
// |         text/x-chdr|      12|
// |  text/pascal-source|      12|
// |application/x-tex...|      12|
// |   application/excel|      12|
// |  application/x-asap|      12|
// |application/x-sho...|      10|
// | application/x-excel|      10|
// |application/x-msa...|      10|
// |           image/xbm|      10|
// |application/x-object|      10|
// |application/x-sgi...|      10|
// |     application/csv|      10|
// |video/x-pn-realvi...|       8|
// |   application/corel|       8|
// |               php/3|       8|
// |      text/scriptlet|       8|
// |     application/doc|       8|
// | binary/octet-stream|       8|
// |       text/x-setext|       8|
// | text/x-include-file|       8|
// | application/java-vm|       8|
// |     application/pgp|       8|
// |  application/x-shar|       8|
// |        image/x-djvu|       8|
// |            text/x-c|       8|
// |application/x-lin...|       8|
// |             img/png|       6|
// |           image/svg|       6|
// |    applicatin/x-rpm|       6|
// |                 wml|       6|
// |   text/x-javascript|       6|
// |           text/news|       6|
// |           text/bugs|       6|
// |application/msreader|       6|
// |            vms/help|       6|
// |application/x-aut...|       6|
// |           ext/plain|       6|
// |  application/winhlp|       6|
// |application/ocet-...|       6|
// |          image/icon|       4|
// |       audio/mpegurl|       4|
// |application/unix-tar|       4|
// |       text/richtext|       4|
// |application/x-jav...|       4|
// |        text/badtype|       4|
// |image/x-portable-...|       4|
// |application/javas...|       4|
// |   text/octet-stream|       4|
// |    application/word|       4|
// |         binary/jpeg|       4|
// |application/pkix-crl|       4|
// |         image/x-xbm|       4|
// |             tks/vnd|       4|
// |application/pkix-...|       4|
// |          text/index|       4|
// |            text/new|       4|
// |         text/readme|       4|
// |           text/jpeg|       4|
// |application/x-mse...|       4|
// |       audio/unknown|       4|
// |application/x-cor...|       4|
// |           text/show|       4|
// |application/java-...|       4|
// |application/x-unk...|       2|
// |           video/avi|       2|
// |    httpd/send-as-is|       2|
// |        text/copying|       2|
// |application/x-pkcs12|       2|
// |image/xv0b2r6axnp...|       2|
// |      text/rss-stats|       2|
// |        text/article|       2|
// |application/x-mac...|       2|
// | application/msexcel|       2|
// |image/mfubmvyx3d5...|       2|
// |         text/spamrc|       2|
// |     text/newsreader|       2|
// |      audio/x-ms-wax|       2|
// |image/jpegcontent...|       2|
// |application/x-pki...|       2|
// |           text/todo|       2|
// |           audio/m3u|       2|
// |interface/x-winam...|       2|
// |application/x-x50...|       2|
// |     applicatpliczip|       2|
// |     multipart/x-zip|       2|
// |    application/gzip|       2|
// |   application/x-deb|       2|
// |      application/ps|       2|
// |application/x-exe...|       2|
// |  application/x-gimp|       2|
// |         video/x-fli|       2|
// |          image/html|       2|
// |        content-type|       2|
// |application/x-net...|       2|
// |        text/version|       2|
// |application/x-htt...|       2|
// |     default-handler|       2|
// |      audio/x-ms-wma|       2|
// |  application/x-diff|       2|
// +--------------------+--------+

// %%
df.where("status == '200'").groupBy("mime").count().orderBy(desc("mime")).cache().show(250)
// Out:
// +--------------------+--------+
// |                mime|   count|
// +--------------------+--------+
// |      x-world/x-vrml|     166|
// |         www/unknown|     144|
// |                 wml|       6|
// |            vms/help|       6|
// |             vms/exe|      32|
// |video/x-pn-realvi...|       8|
// |     video/x-msvideo|     216|
// |      video/x-ms-wmv|      30|
// |      video/x-ms-asf|     274|
// |         video/x-fli|       2|
// |       video/unknown|      48|
// |     video/quicktime|     218|
// |          video/mpeg|     680|
// |           video/avi|       2|
// |                 unk|   12556|
// |        udio/x-scpls|      48|
// |             tks/vnd|       4|
// |            text/xml|    8188|
// |        text/x-vcard|      32|
// |          text/x-tex|     106|
// |          text/x-tcl|     154|
// |           text/x-sh|      36|
// |         text/x-sgml|      20|
// |       text/x-setext|       8|
// |text/x-server-par...|     142|
// |       text/x-pascal|      98|
// |   text/x-javascript|       6|
// |         text/x-java|     208|
// | text/x-include-file|       8|
// |         text/x-csrc|      50|
// |         text/x-chdr|      12|
// |       text/x-c-code|      12|
// |            text/x-c|       8|
// |            text/vnd|    2926|
// |        text/version|       2|
// |           text/todo|       2|
// |text/tab-separate...|      22|
// |         text/spamrc|       2|
// |           text/show|       4|
// |           text/sgml|      46|
// |      text/scriptlet|       8|
// |            text/rtf|     364|
// |      text/rss-stats|       2|
// |       text/richtext|       4|
// |         text/readme|       4|
// |          text/plain|  849752|
// |  text/pascal-source|      12|
// |   text/octet-stream|       4|
// |     text/newsreader|       2|
// |           text/news|       6|
// |            text/new|       4|
// |           text/jpeg|       4|
// |     text/javascript|     762|
// |          text/index|       4|
// |           text/html|27328568|
// |            text/css|  115564|
// |        text/copying|       2|
// |text/comma-separa...|      28|
// |       text/c-source|      46|
// |           text/bugs|       6|
// |        text/badtype|       4|
// |        text/article|       2|
// |         scene/blend|      12|
// |               php/3|       8|
// |                 ose|     844|
// |     multipart/x-zip|       2|
// |          model/vrml|     210|
// |      message/rfc822|      52|
// |        message/news|      72|
// | magnus-internal/cgi|      32|
// |          javascript|      56|
// |interface/x-winam...|       2|
// |             img/png|       6|
// |image/xv0b2r6axnp...|       2|
// |           image/xbm|      10|
// |     image/x-xpixmap|      18|
// |         image/x-xbm|       4|
// |     image/x-xbitmap|    1442|
// |image/x-portable-...|       4|
// |         image/x-png|      50|
// |      image/x-ms-bmp|     646|
// |        image/x-icon|     250|
// |        image/x-djvu|       8|
// |      image/x-bitmap|      22|
// |           image/vnd|      74|
// |           image/url|      18|
// |          image/tiff|     354|
// |           image/swf|      24|
// |           image/svg|       6|
// |           image/png|   82098|
// |         image/pjpeg|    1954|
// |image/mfubmvyx3d5...|       2|
// |           image/jpg|      76|
// |image/jpegcontent...|       2|
// |          image/jpeg| 2896882|
// |          image/icon|       4|
// |           image/ico|      24|
// |          image/html|       2|
// |           image/gif| 3449178|
// |           image/bmp|    3706|
// |        image/bitmap|      32|
// |              image/|      56|
// |httpd/unix-directory|      82|
// |httpd/send-as-is-...|      24|
// |    httpd/send-as-is|       2|
// |           httpd/gra|      22|
// |           ext/plain|       6|
// |            ext/html|      34|
// |       drawing/x-dwf|      30|
// |     default-handler|       2|
// |        content-type|       2|
// |      chemical/x-pdb|      38|
// | binary/octet-stream|       8|
// |         binary/jpeg|       4|
// |         audio/x-wav|    1318|
// |       audio/x-scpls|      64|
// |   audio/x-realaudio|      90|
// |audio/x-pn-realau...|     664|
// |audio/x-pn-realaudio|    7736|
// |      audio/x-ms-wma|       2|
// |      audio/x-ms-wax|       2|
// |     audio/x-mpegurl|    2562|
// |        audio/x-mpeg|      88|
// |         audio/x-mp3|      48|
// |        audio/x-aiff|      74|
// |           audio/wav|      50|
// |       audio/unknown|       4|
// |       audio/mpegurl|       4|
// |         audio/mpeg3|      30|
// |          audio/mpeg|    2792|
// |          audio/midi|     856|
// |           audio/mid|      30|
// |           audio/m3u|       2|
// |         audio/basic|     118|
// |     applicatpliczip|       2|
// |     application/zip|   10212|
// |     application/xml|      14|
// |application/x-zip...|     248|
// |   application/x-zip|      12|
// |application/x-x50...|       2|
// |application/x-x50...|     148|
// |application/x-wai...|      32|
// |application/x-unk...|       2|
// |application/x-tro...|      32|
// |application/x-tro...|      22|
// | application/x-troff|     126|
// | application/x-trash|      22|
// |   application/x-tgz|      90|
// |application/x-tex...|      12|
// |   application/x-tex|    1040|
// |   application/x-tcl|     544|
// |   application/x-tar|    2244|
// |application/x-stu...|      12|
// |application/x-sho...|      10|
// |application/x-sho...|    1864|
// |  application/x-shar|       8|
// |    application/x-sh|     166|
// |application/x-sgi...|      10|
// |   application/x-rpr|      82|
// |   application/x-rpm|     462|
// |application/x-rar...|      32|
// |   application/x-rar|      88|
// |application/x-poi...|     366|
// |application/x-pki...|       2|
// |application/x-pkc...|      32|
// |application/x-pkcs12|       2|
// |  application/x-perl|      68|
// |application/x-object|      10|
// |application/x-ns-...|      32|
// |application/x-netcdf|     142|
// |application/x-net...|       2|
// |application/x-msw...|      32|
// |application/x-msm...|      82|
// |application/x-mse...|       4|
// |application/x-msd...|      44|
// |application/x-msd...|    5064|
// |application/x-msa...|      10|
// |application/x-mac...|       2|
// |   application/x-lzx|      30|
// |application/x-lin...|       8|
// |application/x-jav...|   55150|
// |application/x-jav...|       4|
// |  application/x-java|     214|
// |   application/x-ica|      24|
// |application/x-htt...|      16|
// |application/x-htt...|      14|
// |application/x-htt...|       2|
// |application/x-htt...|     270|
// |application/x-htt...|     232|
// |   application/x-hdf|     114|
// |  application/x-gzip|     178|
// |application/x-gunzip|      22|
// |  application/x-gtar|     146|
// |  application/x-gimp|       2|
// |application/x-fut...|      36|
// |application/x-exe...|       2|
// | application/x-excel|      10|
// |   application/x-dvi|      74|
// |application/x-dir...|     806|
// |  application/x-diff|       2|
// |application/x-deb...|      76|
// |   application/x-deb|       2|
// |application/x-cor...|       4|
// |application/x-com...|      88|
// |application/x-com...|      26|
// |application/x-che...|      18|
// |   application/x-cdf|      36|
// | application/x-bzip2|      48|
// |application/x-aut...|       6|
// |  application/x-asap|      12|
// |    application/word|       4|
// |  application/winhlp|       6|
// |     application/vnd|     684|
// |application/unix-tar|       4|
// |    application/smil|     258|
// |     application/rtf|     206|
// |     application/rar|      12|
// |      application/ps|       2|
// |     application/pps|     130|
// |application/power...|      36|
// |application/posts...|    2118|
// |application/pkix-crl|       4|
// |application/pkix-...|       4|
// |application/pgp-s...|      18|
// |     application/pgp|       8|
// |     application/pdf|    4578|
// |application/octet...|   87790|
// |application/ocet-...|       6|
// |  application/msword|    1548|
// |application/msreader|       6|
// | application/msexcel|       2|
// |application/mac-c...|      24|
// |application/mac-b...|      38|
// |application/javas...|       4|
// | application/java-vm|       8|
// |application/java-...|       4|
// |    application/gzip|       2|
// |application/font-...|      30|
// |     application/exe|      18|
// |   application/excel|      12|
// |application/dos-e...|      60|
// |     application/doc|       8|
// |     application/csv|      10|
// |application/corel...|    4208|
// |   application/corel|       8|
// |    applicatin/x-rpm|       6|
// |     aplications/dwg|     110|
// |           alexa/dat| 1384634|
// +--------------------+--------+

// %%
// for tests - liczba wersji na origina;Url

val vBu = df.groupBy("originalUrl").agg(countDistinct("digest") as "distDigests").cache()

// %%
vBu.show()
// Out:
// +--------------------+-----------+
// |         originalUrl|distDigests|
// +--------------------+-----------+
// |http://www.sunsmi...|          3|
// |http://www.tai.co...|          1|
// |http://www.tchik....|          1|
// |http://www.techla...|          3|
// |http://unikom.com...|          2|
// |http://www.win.co...|          1|
// |http://www.wirtua...|          2|
// |http://www.wirusy...|          1|
// |http://spider.wmc...|          3|
// |http://www.wsip.c...|          1|
// |http://www.wyborc...|          1|
// |http://www.zoltri...|          1|
// |http://www.hotele...|          1|
// |http://katalog.wp...|          2|
// |http://kuchnia.wp...|          2|
// |http://szukaj.wp....|          1|
// |http://szukaj.wp....|          1|
// |http://wyborcza.g...|         48|
// |http://www.muzeum...|          1|
// |http://cenzor.zie...|          1|
// +--------------------+-----------+
// only showing top 20 rows

// %%
// avg
vBu.agg(avg("distDigests") as "avgDigests").show()
// Out:
// +------------------+
// |        avgDigests|
// +------------------+
// |1.1655159763494718|
// +------------------+

// %%
vBu.agg(expr("percentile(distDigests, 0.5)").as("medDigests")).cache().show()
// Out:
// +----------+
// |medDigests|
// +----------+
// |       1.0|
// +----------+
